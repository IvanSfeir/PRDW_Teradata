# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../Data/referentials/referentiel-comptages-routiers+arrondissements (1).csv', header=None, delimiter=';')

# %%
df.head()
# Out:
#       0       1       2    3  \
# 0  1009  1106.0  4301.0  0.0
# 1  1013  1110.0  5868.0  0.0
# 2  1016  1114.0   242.0  0.0
# 3  1027  1125.0  1368.0  0.0
# 4  1028  1126.0  1366.0  0.0
#
#                                                    4         5          6  \
# 0  {"type": "LineString", "coordinates": [[2.2879...  2.286682  48.880469
# 1  {"type": "LineString", "coordinates": [[2.4033...  2.404492  48.836202
# 2  {"type": "LineString", "coordinates": [[2.3237...  2.323437  48.868812
# 3  {"type": "LineString", "coordinates": [[2.3668...  2.366342  48.863919
# 4  {"type": "LineString", "coordinates": [[2.3658...  2.365704  48.864964
#
#        7
# 0  75017
# 1  75012
# 2  75008
# 3  75011
# 4  75011

# %%
import ast

# %%
for i, row in df.iterrows():
    df.at[i,8] = str(ast.literal_eval(row[4])["coordinates"][0][0])
    df.at[i,9] = str(ast.literal_eval(row[4])["coordinates"][0][1])
    df.at[i,10] = str(ast.literal_eval(row[4])["coordinates"][-1][0])
    df.at[i,11] = str(ast.literal_eval(row[4])["coordinates"][-1][1])

# %%
a = ast.literal_eval(df.iloc[3,4])["coordinates"][0]

# %%
a = ast.literal_eval(df.iloc[4,4])["coordinates"][-1]

# %%
a[1]
# Out:
# 48.865263992289414

# %%
df[9] = list(df[1])

# %%
df.head()
# Out:
#      0       1       2    3   \
# 0  1009  1106.0  4301.0  0.0
# 1  1013  1110.0  5868.0  0.0
# 2  1016  1114.0   242.0  0.0
# 3  1027  1125.0  1368.0  0.0
# 4  1028  1126.0  1366.0  0.0
#
#                                                   4         5          6   \
# 0  {"type": "LineString", "coordinates": [[2.2879...  2.286682  48.880469
# 1  {"type": "LineString", "coordinates": [[2.4033...  2.404492  48.836202
# 2  {"type": "LineString", "coordinates": [[2.3237...  2.323437  48.868812
# 3  {"type": "LineString", "coordinates": [[2.3668...  2.366342  48.863919
# 4  {"type": "LineString", "coordinates": [[2.3658...  2.365704  48.864964
#
#       7         8          9                  10                  11
# 0  75017  2.287980  48.880174  2.285383675647954   48.88076386470787
# 1  75012  2.403380  48.836600  2.405605028484108  48.835804317659544
# 2  75008  2.323723  48.869214  2.323151002200044  48.868409464016445
# ...

# %%
df.to_csv('../Data/referentials/referentiel-comptages-routiers+arrondissements+limites.csv', header=None, sep=';', index=False)

# %%
pd.read_csv('../Data/referentials/referentiel-comptages-routiers+arrondissements+limites.csv', header=None, delimiter=';').head()
# Out:
#      0       1       2    3   \
# 0  1009  1106.0  4301.0  0.0
# 1  1013  1110.0  5868.0  0.0
# 2  1016  1114.0   242.0  0.0
# 3  1027  1125.0  1368.0  0.0
# 4  1028  1126.0  1366.0  0.0
#
#                                                   4         5          6   \
# 0  {"type": "LineString", "coordinates": [[2.2879...  2.286682  48.880469
# 1  {"type": "LineString", "coordinates": [[2.4033...  2.404492  48.836202
# 2  {"type": "LineString", "coordinates": [[2.3237...  2.323437  48.868812
# 3  {"type": "LineString", "coordinates": [[2.3668...  2.366342  48.863919
# 4  {"type": "LineString", "coordinates": [[2.3658...  2.365704  48.864964
#
#       7         8          9         10         11
# 0  75017  2.287980  48.880174  2.285384  48.880764
# 1  75012  2.403380  48.836600  2.405605  48.835804
# 2  75008  2.323723  48.869214  2.323151  48.868409
# 3  75011  2.366809  48.863175  2.365876  48.864664
# 4  75011  2.365876  48.864664  2.365531  48.865264

# %%
# Out:
#         0       1       2    3   \
# 1     1013  1110.0  5868.0  0.0
# 2     1016  1114.0   242.0  0.0
# 3     1027  1125.0  1368.0  0.0
# 4     1028  1126.0  1366.0  0.0
# 5     1029  1127.0  1363.0  0.0
# 6     1033  1131.0  1377.0  0.0
# 7     1041  1139.0   376.0  0.0
# 8     1043  1141.0   373.0  0.0
# 9     1052  1150.0   176.0  0.0
# 10    1053  1151.0    30.0  0.0
# 11    1056  1154.0    33.0  0.0
# 12    1058  1156.0    35.0  0.0
# 13    1063  1162.0   430.0  0.0
# 14    1081  1180.0    65.0  0.0
# 15    1088  1187.0  4184.0  0.0
# 16    1098  1197.0    13.0  0.0
# 17    1099  1198.0    14.0  0.0
# 18    1102  1201.0   327.0  0.0
# 19    1104  1203.0   332.0  0.0
# 20    1108  1207.0   195.0  0.0
# 21    1112  1211.0   160.0  0.0
# 22    1113  1212.0   161.0  0.0
# 23    1119  1220.0   533.0  0.0
# 24    1125  1226.0    51.0  0.0
# 25    1153  1255.0  6744.0  0.0
# 26    1211  1317.0   440.0  0.0
# 27    1376  1665.0  5915.0  0.0
# 28    1389  1679.0  6637.0  0.0
# ...
