# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../Data/traffic/donnees_trafic_capteurs.csv', header=None, delimiter='\t')
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.sample
# Out:
# <bound method NDFrame.sample of              0                    1     2    3
# 0            1  2016-01-01 01:00:00  1560  5,3
# 1            1  2016-01-01 02:00:00  1640  5,3
# 2            1  2016-01-01 03:00:00  1484    5
# 3            1  2016-01-01 04:00:00  1174  3,8
# 4            1  2016-01-01 05:00:00   977  3,1
# 5            1  2016-01-01 06:00:00   798  2,5
# 6            1  2016-01-01 07:00:00   533    2
# 7            1  2016-01-01 08:00:00   314    1
# 8            1  2016-01-01 09:00:00   589  1,7
# 9            1  2016-01-01 10:00:00   637    2
# 10           1  2016-01-01 11:00:00   810  2,7
# 11           1  2016-01-01 12:00:00  1265  4,3
# 12           1  2016-01-01 13:00:00  1647    5
# 13           1  2016-01-01 14:00:00  1599  4,6
# 14           1  2016-01-01 15:00:00  1681  5,2
# 15           1  2016-01-01 16:00:00  2033  6,2
# 16           1  2016-01-01 17:00:00  2121  7,1
# 17           1  2016-01-01 18:00:00  1536  5,7
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of              0                    1     2    3
# 0            1  2016-01-01 01:00:00  1560  5,3
# 1            1  2016-01-01 02:00:00  1640  5,3
# 2            1  2016-01-01 03:00:00  1484    5
# 3            1  2016-01-01 04:00:00  1174  3,8
# 4            1  2016-01-01 05:00:00   977  3,1
# 5            1  2016-01-01 06:00:00   798  2,5
# 6            1  2016-01-01 07:00:00   533    2
# 7            1  2016-01-01 08:00:00   314    1
# 8            1  2016-01-01 09:00:00   589  1,7
# 9            1  2016-01-01 10:00:00   637    2
# 10           1  2016-01-01 11:00:00   810  2,7
# 11           1  2016-01-01 12:00:00  1265  4,3
# 12           1  2016-01-01 13:00:00  1647    5
# 13           1  2016-01-01 14:00:00  1599  4,6
# 14           1  2016-01-01 15:00:00  1681  5,2
# 15           1  2016-01-01 16:00:00  2033  6,2
# 16           1  2016-01-01 17:00:00  2121  7,1
# 17           1  2016-01-01 18:00:00  1536  5,7
# ...

# %%
len(df[df[1] == 0])
# Out:
# 0

# %% [markdown]
# **Results:**
# Total Rows Sent To RDBMS:      72982478
# Total Rows Applied:            72699182
# Total Duplicate Rows:            283296
# Total Dataframe Rows:          72982478

# %%
duplicate_indexes = df.index[df.duplicated()]

# %%
df[df[1].isnull()]
# Out:
# Empty DataFrame
# Columns: [0, 1, 2, 3]
# Index: []

# %%
duplicate_indexes[50:]
# Out:
# Int64Index([ 6373730,  6373731,  6373732,  6373733,  6373734,  6373735,
#              6373736,  6373737,  6373738,  6373739,
#             ...
#             68552580, 68552581, 68552582, 68552583, 68552584, 68552585,
#             68552586, 68552587, 68552588, 68552589],
#            dtype='int64', length=264491)

# %%
df.iloc[6372288]
# Out:
# 0                      1
# 1    2016-04-01 01:00:00
# 2                   1011
# 3                    2,9
# Name: 6372288, dtype: object

# %%
df.iloc[6372289]
# Out:
# 0                      1
# 1    2016-04-01 02:00:00
# 2                    621
# 3                      2
# Name: 6372289, dtype: object

# %%
df.iloc[duplicate_indexes[:24]]
# Out:
#          0                    1     2     3
# 6372288  1  2016-04-01 01:00:00  1011   2,9
# 6372289  1  2016-04-01 02:00:00   621     2
# 6372290  1  2016-04-01 03:00:00   411   1,4
# 6372291  1  2016-04-01 04:00:00   266     1
# 6372292  1  2016-04-01 05:00:00   225    ,9
# 6372293  1  2016-04-01 06:00:00   274     1
# 6372294  1  2016-04-01 07:00:00   585   1,9
# 6372295  1  2016-04-01 08:00:00  1171   3,1
# 6372296  1  2016-04-01 09:00:00  1870   4,7
# 6372297  1  2016-04-01 10:00:00  2105     5
# 6372298  1  2016-04-01 11:00:00  1848   5,3
# 6372299  1  2016-04-01 12:00:00  1948     5
# 6372300  1  2016-04-01 13:00:00  1706  27,5
# 6372301  1  2016-04-01 14:00:00  1620   9,3
# 6372302  1  2016-04-01 15:00:00  1723  10,9
# 6372303  1  2016-04-01 16:00:00  1745  15,1
# 6372304  1  2016-04-01 17:00:00  1680  21,9
# 6372305  1  2016-04-01 18:00:00  1717  14,3
# 6372306  1  2016-04-01 19:00:00  1834   5,4
# 6372307  1  2016-04-01 20:00:00  1996   4,9
# ...

# %%
df.iloc[duplicate_indexes[140000:150000]]
# Out:
#              0                    1    2    3
# 51420496   586  2018-01-01 06:00:00  NaN  NaN
# 51420497   586  2018-01-01 07:00:00  NaN  NaN
# 51420498   586  2018-01-01 08:00:00  NaN  NaN
# 51420499   586  2018-01-01 09:00:00  NaN  NaN
# 51420500   586  2018-01-01 10:00:00  NaN  NaN
# 51420501   586  2018-01-01 11:00:00  NaN  NaN
# 51420502   586  2018-01-01 12:00:00  NaN  NaN
# 51420503   586  2018-01-01 13:00:00  NaN  NaN
# 51420504   586  2018-01-01 14:00:00  NaN  NaN
# 51420505   586  2018-01-01 15:00:00  NaN  NaN
# 51420506   586  2018-01-01 16:00:00  NaN  NaN
# 51420507   586  2018-01-01 17:00:00  NaN  NaN
# 51420508   586  2018-01-01 18:00:00  NaN  NaN
# 51420509   586  2018-01-01 19:00:00  NaN  NaN
# 51420510   586  2018-01-01 20:00:00  NaN  NaN
# 51420511   586  2018-01-01 21:00:00  NaN  NaN
# 51420512   586  2018-01-01 22:00:00  NaN  NaN
# 51420513   586  2018-01-01 23:00:00  NaN  NaN
# 51420514   586  2018-01-02 00:00:00  NaN  NaN
# ...

# %% [markdown]
# No duplicates in donnees_traffic_capteurs_201604.txt:

# %%
df1604 = pd.read_csv('../Data/traffic/donnees_trafic_capteurs_201604.txt', header=None, delimiter='\t')
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
duplicate_indexes1604 = df1604.index[df1604.duplicated()]

# %%
len(duplicate_indexes1604)
# Out:
# 0

# %%
72982478/34/30
# Out:
# 71551.44901960784

# %%
30*34
# Out:
# 1020

# %%
from itertools import chain, combinations

# %%
def key_options(items):
    return chain.from_iterable(combinations(items, r) for r in range(1, len(items)+1) )

# %%
# iterate over all combos of headings, excluding ID for brevity
for candidate in key_options(list(df)):
    deduped = df.drop_duplicates(candidate)

    if len(deduped.index) == len(df.index):
        print(','.join(candidate))
